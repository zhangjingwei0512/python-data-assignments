# %%
import csv
list1=['','','','','']
list2=['trade-wars-news1.txt','trade-wars-news2.txt','trade-wars-news3.txt','trade-wars-news4.txt','trade-wars-news5.txt']
for i in range(0,5):
    list1[i]=open(list2[i],'r+',encoding='UTF-8')
    list1[i]=list1[i].read()
    list1[i]=list1[i].strip()
    list1[i]=list1[i].replace('\n','')
    list1[i]=list1[i].replace('“','')
    list1[i]=list1[i].replace('”','')
    list1[i]=list1[i].replace(',','')
    list1[i]=list1[i].replace(':','')
    list1[i]=list1[i].replace('(','')
    list1[i]=list1[i].replace(')','')
    list1[i]=list1[i].replace('？','')
    list1[i]=list1[i].replace('‘','')
    list1[i]=list1[i].replace('[','')
    list1[i]=list1[i].replace(']','')
    list1[i]=list1[i].replace('.','').lower().split()
wordlist=list1[0]+list1[1]+list1[2]+list1[3]+list1[4]
wordlist
# Out:
# 5465

# %%
stop_words=['the','and','of','a','in','to','that','is','as','on','with','it','for','has','are','not','have','its','from','would','by','this','at','be','which','an','up','said','also','they','about','but']
countlist={}
for word in wordlist:
    if word in countlist.keys():
        countlist[word]=countlist[word]+1
    else:
        countlist[word]=1
countlist
# Out:
# {'utterly': 2,
#  'messed': 2,
#  'up': 18,
#  'my': 7,
#  'life': 3,
#  'what': 3,
#  'chinese': 48,
#  'people': 8,
#  'really': 1,
#  'think': 2,
#  'of': 150,
#  'the': 346,
#  'trade': 54,
#  'warthe': 2,
#  'guardian': 1,
#  'by': 21,
#  'echo': 1,
#  'huangoctober': 1,
#  '9': 3,
#  '2018china’s': 2,
#  'ardent': 1,
#  'determination': 1,
#  'to': 189,
#  'win': 2,
#  'war': 34,
#  'might': 5,
#  'not': 28,
#  'have': 28,
#  'all': 10,
#  'public': 4,
#  'support': 2,
#  'it': 37,
#  'would': 22,
#  'likesince': 1,
#  'us': 67,
#  'and': 137,
#  'china': 62,
#  'entered': 1,
#  'a': 129,
#  'in': 108,
#  'earnest': 1,
#  'this': 21,
#  'year': 8,
#  'both': 4,
#  'sides': 2,
#  'been': 12,
#  'going': 8,
#  'tit-for-tat': 1,
#  'with': 49,
#  'increasing': 3,
#  'tariffs': 22,
#  'on': 52,
#  'goods': 7,
#  'has': 31,
#  'put': 4,
#  'new': 12,
#  '$250': 1,
#  'billion': 9,
#  'imports': 4,
#  'while': 11,
#  'done': 2,
#  'same': 3,
#  '$110': 1,
#  'worth': 2,
#  'china’s': 15,
#  'running': 1,
#  'out': 9,
#  'keep': 2,
#  'retaliation': 1,
#  'its': 27,
#  'strongest': 2,
#  'weapon': 1,
#  'national': 3,
#  'fate': 1,
#  'is': 61,
#  'spirit': 2,
#  'according': 2,
#  'state': 9,
#  'mediathe': 1,
#  'heroism': 1,
#  'being': 1,
#  'first': 6,
#  'show': 4,
#  'concern': 1,
#  'last': 13,
#  'enjoy': 1,
#  'oneself’': 1,
#  'always': 3,
#  'run': 2,
#  'through': 3,
#  'blood': 1,
#  'which': 19,
#  'also': 15,
#  'includes': 1,
#  'sacrificing': 1,
#  'one’s': 1,
#  'interest': 2,
#  'for': 36,
#  'greater': 3,
#  'good': 4,
#  "public'": 1,
#  'said': 18,
#  'an': 19,
#  'opinion': 2,
#  'piece': 1,
#  'link': 7,
#  'posted': 1,
#  'state-run': 3,
#  'people’s': 1,
#  'daily': 2,
#  'july': 1,
#  '10': 3,
#  'facing': 1,
#  'fate’': 1,
#  'are': 31,
#  'deeply': 2,
#  'aware': 1,
#  'that': 70,
#  'there’s': 3,
#  'no': 6,
#  'home': 2,
#  'without': 2,
#  'country’': 1,
#  'so': 10,
#  'they': 14,
#  'willing': 6,
#  'bear': 1,
#  'temporary': 1,
#  'lossesthat': 1,
#  'comment': 2,
#  'doesn’t': 3,
#  'acknowledge': 2,
#  'how': 8,
#  'painful': 1,
#  'could': 9,
#  'become': 5,
#  'common': 5,
#  'economists': 1,
#  'estimate': 1,
#  'if': 12,
#  'latest': 1,
#  'be': 20,
#  'added': 2,
#  'see': 11,
#  'go': 3,
#  '25%': 1,
#  'next': 4,
#  'shave': 1,
#  'half': 2,
#  'percentage': 1,
#  'point': 4,
#  'off': 2,
#  'growth': 3,
#  'online': 2,
#  'sharing': 1,
#  'they’re': 1,
#  'experiencing': 1,
#  'impacts': 1,
#  'far': 6,
#  'worrying': 4,
#  'about': 14,
#  'what’s': 2,
#  'comestocks': 1,
#  'tumble': 3,
#  'yuan': 2,
#  'devalueson': 1,
#  'monday': 5,
#  'oct7': 1,
#  'day': 3,
#  'after': 5,
#  'golden': 1,
#  'week': 6,
#  'holiday': 1,
#  'stocks': 1,
#  'fell': 2,
#  'sharply': 1,
#  'benchmark': 1,
#  'shanghai': 1,
#  'composite': 1,
#  'index': 2,
#  '37%—its': 1,
#  'biggest': 1,
#  'single-day': 1,
#  'loss': 1,
#  'paywall': 2,
#  'more': 16,
#  'than': 8,
#  'three': 2,
#  'months': 1,
#  'stock': 7,
#  'came': 1,
#  'central': 5,
#  'bank': 2,
#  'announced': 1,
#  'cut': 1,
#  'reserve': 1,
#  'requirement': 3,
#  'ratio': 1,
#  'commercial': 1,
#  'banks': 1,
#  'fourth': 1,
#  'time': 6,
#  'year—a': 1,
#  'move': 2,
#  'seen': 3,
#  'as': 55,
#  'trying': 2,
#  'boost': 2,
#  'economy': 9,
#  'liquidity': 1,
#  'amid': 1,
#  'general': 1,
#  'markets': 3,
#  'haven’t': 2,
#  'taking': 1,
#  'stridethis': 1,
#  'tough': 1,
#  'me': 2,
#  'i': 11,
#  'received': 1,
#  'payments': 1,
#  'several': 1,
#  'projects': 2,
#  'because': 6,
#  'bursts': 1,
#  'wrote': 6,
#  'user': 4,
#  'social': 1,
#  'media': 2,
#  'platform': 1,
#  'weibo': 3,
#  'who': 8,
#  'identified': 1,
#  'himself': 4,
#  'working': 2,
#  'at': 21,
#  'securities': 1,
#  'firm': 2,
#  'beijing': 18,
#  'market’s': 1,
#  'killed': 1,
#  'many': 5,
#  'when': 5,
#  'returned': 1,
#  'village': 1,
#  'officials': 3,
#  'asked': 4,
#  'how’s': 1,
#  'work': 2,
#  'answer': 2,
#  'sadly': 1,
#  'was': 13,
#  'this—deleveraging': 1,
#  'bad': 1,
#  'performance': 1,
#  'lifereuters/mariana': 1,
#  'bazolooking': 1,
#  'marketsthe': 1,
#  'devalued': 1,
#  'worried': 3,
#  'help': 2,
#  'exporters': 1,
#  'making': 2,
#  'their': 7,
#  'competitive': 1,
#  'makes': 1,
#  'tougher': 1,
#  'need': 3,
#  'foreign': 10,
#  'currency': 2,
#  'example': 1,
#  'families': 1,
#  'hundreds': 2,
#  'thousands': 2,
#  'studying': 1,
#  'abroadwe': 1,
#  'now': 6,
#  'kneeling': 1,
#  'it’s': 3,
#  'hard': 2,
#  'rmb': 1,
#  'renminbi': 1,
#  'can': 9,
#  'stable': 1,
#  'near': 1,
#  'term': 1,
#  'looks': 1,
#  'like': 2,
#  'great': 2,
#  'depression': 1,
#  'arrive': 1,
#  'chinesesnacks': 1,
#  'oil': 3,
#  'prices': 2,
#  'uptreats': 1,
#  'suddenly': 2,
#  'expensive': 2,
#  'due': 1,
#  'necessitiesi': 1,
#  'ran': 2,
#  'nuts': 3,
#  'yesterday': 1,
#  'wanted': 1,
#  'top': 3,
#  'female': 1,
#  'based': 3,
#  'northern': 1,
#  'hebei': 1,
#  'province': 2,
#  'but': 14,
#  'she': 2,
#  'found': 2,
#  'she’s': 1,
#  'used': 1,
#  'eating': 1,
#  'every': 2,
#  'including': 6,
#  'pecans': 1,
#  'commonly': 1,
#  'sourced': 1,
#  'from': 25,
#  'cost': 2,
#  'her': 1,
#  'morei': 1,
#  'shop': 1,
#  'owner': 2,
#  'why': 4,
#  'time?’': 1,
#  'continued': 1,
#  'him': 3,
#  'relationship?’': 1,
#  'he': 12,
#  'had': 8,
#  'imported': 1,
#  'lots': 1,
#  'overseas': 2,
#  'feel': 2,
#  'impact': 1,
#  'waras': 1,
#  'maine': 1,
#  'lobster': 1,
#  'forget': 1,
#  'itchinese': 1,
#  'drivers': 1,
#  'feeling': 1,
#  'pinch': 1,
#  'putting': 1,
#  'augusti’ve': 1,
#  'felt': 1,
#  'economic': 11,
#  'environment': 2,
#  'peer-to-peer': 1,
#  'lending': 1,
#  'illegal': 1,
#  'money-raising': 1,
#  'crackdown': 1,
#  'bled': 1,
#  'bunch': 1,
#  'drop': 1,
#  'come': 2,
#  'real': 2,
#  'estate': 1,
#  'market…': 1,
#  'then': 6,
#  'won’t': 2,
#  'long': 7,
#  'before': 2,
#  'can’t': 2,
#  'afford': 1,
#  'car': 1,
#  'chinesesmall': 1,
#  'businesses': 2,
#  'may': 3,
#  'harder': 1,
#  'hit': 2,
#  'larger': 1,
#  'ones': 1,
#  'most': 8,
#  'recent': 5,
#  'caixin': 1,
#  'manufacturing': 3,
#  'purchasing': 1,
#  'managers': 1,
#  'better': 4,
#  'gauge': 1,
#  'sentiment': 1,
#  'smaller': 1,
#  'private': 1,
#  'firms': 2,
#  'official': 1,
#  'pmi': 1,
#  'declined': 1,
#  '506': 1,
#  'august': 1,
#  '50': 2,
#  'month': 4,
#  'lowest': 1,
#  'level': 1,
#  'number': 1,
#  'below': 1,
#  'indicates': 1,
#  'contractionreutersin': 1,
#  'response': 2,
#  'american': 14,
#  'soybean': 1,
#  'importspessimism': 1,
#  'naftapeople': 1,
#  'aren’t': 1,
#  'optimistic': 1,
#  'pressure': 5,
#  'will': 16,
#  'ease': 1,
#  'fact': 3,
#  'north': 1,
#  'free': 5,
#  'agreement': 8,
#  'renegotiated': 1,
#  'mexico': 7,
#  'canada—now': 1,
#  'brand-new': 1,
#  'acronym—shows': 1,
#  'formation': 1,
#  'front': 3,
#  'against': 16,
#  'some': 5,
#  'commenters': 1,
#  'notedwhy': 1,
#  'difficult': 4,
#  'six': 1,
#  'months?': 1,
#  'male': 1,
#  'micro-blogging': 1,
#  'site': 1,
#  'southwestern': 1,
#  'sichuan': 1,
#  'his': 9,
#  'argument': 3,
#  'elements': 2,
#  'key': 2,
#  'driving': 1,
#  'years—including': 1,
#  'infrastructure': 2,
#  'domestic': 5,
#  'demands—have': 1,
#  'shown': 1,
#  'signs': 2,
#  'terms': 2,
#  'americans': 3,
#  'launching': 1,
#  'wars': 3,
#  'worldwide': 1,
#  'want': 4,
#  'bypass': 1,
#  'wto': 1,
#  'world': 7,
#  'organization': 2,
#  'build': 2,
#  'something': 1,
#  'end': 3,
#  'september': 3,
#  'canada': 8,
#  'signed': 1,
#  'cooperation': 1,
#  'non-market-oriented': 2,
#  'wants': 4,
#  'enter': 1,
#  'market': 5,
#  'needs': 2,
#  'approval': 1,
#  'countries…': 1,
#  'everyone': 1,
#  'knows': 2,
#  'economy’': 1,
#  'isthe': 1,
#  'nafta': 3,
#  'asks': 1,
#  'countries': 7,
#  'notify': 1,
#  'each': 4,
#  'other': 10,
#  'deal': 11,
#  'talks': 5,
#  'non-market': 1,
#  'give': 2,
#  'one': 9,
#  'another': 5,
#  'say': 2,
#  'dealamericans': 1,
#  'building': 2,
#  'anti-china': 2,
#  'circle': 1,
#  'round': 2,
#  'gave': 2,
#  'am': 2,
#  'afraid': 1,
#  'third': 1,
#  'japan': 6,
#  'europe': 5,
#  'highly': 2,
#  'suggest': 2,
#  'should': 6,
#  'make': 6,
#  'major': 2,
#  'adjustments': 1,
#  'current': 2,
#  'policies': 4,
#  'instead': 3,
#  'listening': 1,
#  'opinions': 1,
#  'so-called': 3,
#  'elites': 2,
#  'back': 4,
#  'down': 3,
#  'commerce': 3,
#  'ministerscmp': 1,
#  'amanda': 1,
#  'leechina': 1,
#  'cave': 1,
#  'demands': 4,
#  'even': 7,
#  'faces': 1,
#  'further': 5,
#  'exports': 3,
#  'minister': 5,
#  'zhong': 5,
#  'shan': 1,
#  'signalling': 1,
#  'beijing’s': 6,
#  'uncompromising': 1,
#  'stance': 3,
#  'dealing': 1,
#  'usthere': 1,
#  'view': 1,
#  'keeps': 2,
#  'don’t': 1,
#  'know': 4,
#  'history': 3,
#  'culture': 1,
#  'statement': 1,
#  'published': 1,
#  'bloomberg': 1,
#  'newsthis': 1,
#  'unyielding': 1,
#  'nation': 3,
#  'suffered': 1,
#  'bullying': 1,
#  'times': 9,
#  'never': 2,
#  'succumbed': 1,
#  'conditions': 1,
#  'rise': 2,
#  'break': 2,
#  'outthe': 1,
#  'underestimate': 1,
#  'resolve': 2,
#  'willthis': 1,
#  'yet': 4,
#  'following': 2,
#  'release': 1,
#  'white': 2,
#  'paper': 1,
#  'detailing': 1,
#  'blamed': 1,
#  'creating': 1,
#  'tensions': 3,
#  'painted': 1,
#  'itself': 6,
#  'promoter': 1,
#  'tradethe': 2,
#  'strong': 2,
#  'comments': 1,
#  'whose': 2,
#  'ministry': 1,
#  'line': 4,
#  'any': 6,
#  'possible': 1,
#  'coincide': 1,
#  'rapid': 1,
#  'deterioration': 1,
#  'ties': 1,
#  'between': 7,
#  'washingtoncompanies': 1,
#  'consumers': 2,
#  'best': 2,
#  'whether': 4,
#  'or': 8,
#  'taken': 3,
#  'advantage': 4,
#  'ofchina’s': 1,
#  'shanus': 1,
#  'secretary': 4,
#  'mike': 6,
#  'pompeo': 6,
#  'brief': 1,
#  'visit': 1,
#  'testy': 2,
#  'exchange': 3,
#  'wang': 3,
#  'yiwang': 1,
#  'told': 3,
#  'hurt': 2,
#  'mutual': 2,
#  'trust': 1,
#  'must': 3,
#  'stop': 2,
#  'misguided': 1,
#  'actions': 2,
#  'there': 6,
#  'were': 4,
#  'fundamental': 2,
#  'disagreements': 1,
#  'two': 7,
#  'powersprospects': 1,
#  'washington': 2,
#  'de-escalate': 2,
#  'brightthe': 1,
#  'locked': 1,
#  'horns': 1,
#  'levying': 1,
#  'punitive': 2,
#  'gaping': 1,
#  'differences': 1,
#  'over': 8,
#  'slew': 1,
#  'issues': 1,
#  'intellectual': 3,
#  'property': 2,
#  'rights': 3,
#  'role': 2,
#  'state-owned': 2,
#  'enterprisesthe': 1,
#  'initially': 1,
#  'imposed': 2,
#  '25': 3,
#  'per': 6,
#  'cent': 6,
#  'tariff': 4,
#  'us$50': 2,
#  'additional': 1,
#  'us$200': 1,
#  'products': 2,
#  'rate': 1,
#  'set': 2,
#  'january': 1,
#  '1': 2,
#  'does': 2,
#  'concessionschina’s': 1,
#  'pump': 1,
#  'us$110': 1,
#  'into': 5,
#  'intensifiesus': 1,
#  'president': 15,
#  'donald': 5,
#  'trump': 24,
#  'threatened': 2,
#  'extend': 1,
#  'importschina': 1,
#  'retaliated': 1,
#  'variable': 1,
#  '5': 1,
#  'us$60': 1,
#  'importschina’s': 1,
#  'yi': 2,
#  'left': 2,
#  'photo': 1,
#  'apwashington': 1,
#  'demanding': 1,
#  'change': 5,
#  'practices': 1,
#  'forcing': 1,
#  'transfer': 3,
#  'technologies': 2,
#  'subsidising': 1,
#  'enterpriseszhong': 1,
#  'reiterated': 2,
#  'steal': 1,
#  'technology': 4,
#  'firmsi': 1,
#  'emphasise': 1,
#  'laws': 1,
#  'regulations': 1,
#  'do': 7,
#  'contain': 5,
#  'companies’': 1,
#  'purchases': 1,
#  'patents': 1,
#  'pure': 1,
#  'behaviour': 1,
#  'saidchina’s': 1,
#  'development': 1,
#  'science': 1,
#  'technological': 1,
#  'progress': 2,
#  'owed': 1,
#  'reform': 1,
#  'opening': 2,
#  'endeavours': 1,
#  'peopleas': 1,
#  'turns': 1,
#  'heat': 1,
#  'moves': 1,
#  'beyond': 2,
#  'battlefrontszhong': 1,
#  'argued': 2,
#  'took': 4,
#  'country': 4,
#  'record': 1,
#  'surplus': 1,
#  'us$3105': 1,
#  'augustif': 1,
#  'side': 3,
#  'such': 5,
#  'business': 4,
#  'relations': 2,
#  'continued?': 1,
#  'companies': 3,
#  'saidthe': 1,
#  'conflict': 5,
#  'gone': 2,
#  'trump’s': 4,
#  'accusations': 3,
#  'attempting': 3,
#  'interfere': 2,
#  '2018': 3,
#  'midterm': 5,
#  'congressional': 1,
#  'elections': 5,
#  'vice-president': 1,
#  'pence': 9,
#  'stepped': 1,
#  'attack': 1,
#  'condemning': 1,
#  'using': 2,
#  'tool': 1,
#  'disposal': 1,
#  'undermine': 2,
#  'political': 10,
#  'systempence': 1,
#  'warned': 3,
#  'tech': 1,
#  'giant': 1,
#  'alphabet': 1,
#  'owns': 1,
#  'google': 1,
#  'disengage': 1,
#  'rips': 1,
#  'playbook': 2,
#  'take': 4,
#  'chinadonna': 1,
#  'borak': 1,
#  'cnnupdated': 1,
#  '1037': 1,
#  'gmt': 1,
#  '1837': 1,
#  'hkt': 1,
#  'october': 1,
#  '2018bali': 1,
#  'indonesia': 2,
#  'cnnpresident': 1,
#  '—': 2,
#  'just': 6,
#  'anytime': 3,
#  'soonafter': 1,
#  'announcing': 1,
#  'revamped': 1,
#  'reeled': 1,
#  'list': 1,
#  'given': 2,
#  'hold': 2,
#  'south': 3,
#  'korea': 2,
#  'european': 4,
#  'unionhe': 1,
#  'scoffed': 1,
#  'those': 4,
#  '"babies': 1,
#  'there"': 1,
#  'effects': 2,
#  'suggesting': 1,
#  '"we': 3,
#  "wouldn't": 1,
#  'talking': 4,
#  'deal"': 1,
#  'confrontational': 1,
#  'approachthe': 1,
#  'imf': 1,
#  'warns"that\'s': 1,
#  'embolden': 1,
#  'impose': 2,
#  'threaten': 2,
#  'hopes': 1,
#  'getting': 1,
#  'china"': 2,
#  'edward': 1,
#  'alden': 1,
#  'senior': 2,
#  'fellow': 2,
#  'council': 1,
#  "relationstrump's": 1,
#  'no-holds-barred': 1,
#  'strategy': 4,
#  'likely': 3,
#  'center': 1,
#  'stage': 1,
#  'summit': 4,
#  'global': 14,
#  'finance': 3,
#  'chiefs': 1,
#  'bankers': 1,
#  'bali': 1,
#  "it'll": 1,
#  'treasury': 1,
#  'steven': 1,
#  'mnuchin': 1,
#  "president's": 1,
#  'envoy': 1,
#  'argue': 1,
#  'case': 1,
#  'warnings': 1,
#  'intensify': 1,
#  'damage': 2,
#  'protracted': 2,
#  'growth"the': 1,
#  'stakes': 2,
#  'high"': 1,
#  'christine': 1,
#  'lagarde': 1,
#  'managing': 1,
#  'director': 1,
#  'international': 3,
#  'monetary': 1,
#  'fund': 1,
#  'together': 1,
#  'disputes"\'coalition': 1,
#  "willing'if": 1,
#  'administration': 10,
#  'get': 1,
#  'union': 6,
#  'deals': 2,
#  "that's": 1,
#  'strengthen': 1,
#  'negotiating': 1,
#  'position': 1,
#  'argueus': 1,
#  'reach': 2,
#  'naftaus': 1,
#  '0158"we': 1,
#  'again': 2,
#  'we': 9,
#  'moving': 1,
#  'characterized': 1,
#  'coalition': 2,
#  'confront': 1,
#  'larry': 1,
#  'kudlow': 1,
#  "trump's": 1,
#  'chief': 3,
#  'adviser': 1,
#  'weekbut': 1,
#  'still': 3,
#  'early': 4,
#  'stages': 1,
#  'french': 1,
#  'emmanuel': 1,
#  'macron': 1,
#  "shouldn't": 1,
#  'sign': 1,
#  "doesn't": 1,
#  'comply': 1,
#  'paris': 2,
#  'climate': 2,
#  'clear': 3,
#  'reference': 2,
#  'united': 9,
#  'statesthe': 1,
#  "administration's": 1,
#  'approach': 3,
#  'old': 1,
#  'collaboratively': 1,
#  'allies': 2,
#  'address': 3,
#  'concernsother': 1,
#  'big': 1,
#  'economies': 2,
#  'share': 1,
#  'main': 1,
#  'grievances': 1,
#  'theft': 1,
#  'hand': 1,
#  'partners': 1,
#  'slapped': 1,
#  'stepping': 1,
#  'campaign': 3,
#  'analysts': 1,
#  'weakened': 2,
#  'potential': 3,
#  'frontthe': 1,
#  'china&#39;s': 1,
#  'annual': 1,
#  'statessouring': 1,
#  'relationshiptrump': 1,
#  'made': 3,
#  "he's": 1,
#  'rush': 2,
#  'restart': 1,
#  'soon': 3,
#  'bigger': 1,
#  'wave': 1,
#  '$267': 1,
#  'mean': 2,
#  'measures': 1,
#  'effectively': 1,
#  'cover': 1,
#  'sells': 1,
#  'states': 5,
#  'year"i\'m': 1,
#  'them': 2,
#  'negotiate"': 1,
#  '"and': 1,
#  'hopefully': 1,
#  'fair': 1,
#  'reciprocal': 1,
#  'deal"trade': 1,
#  'looms': 2,
#  'chiefstrade': 1,
#  'chiefsdetails': 1,
#  'revised': 1,
#  'pact': 1,
#  'replace': 1,
#  'government': 3,
#  'ways': 2,
#  'amplify': 1,
#  'chinatucked': 1,
#  'inform': 1,
#  'others': 2,
#  'start': 1,
#  'negotiations': 1,
#  '"non-market': 1,
#  'economy"': 1,
#  'able': 1,
#  'review': 1,
#  'chinathat': 1,
#  'upset': 1,
#  'souring': 1,
#  'relationship': 3,
#  'superpowersin': 1,
#  'frank': 1,
#  'views': 1,
#  'immediately': 1,
#  '"wrong': 1,
#  'remarks': 2,
#  'actions"': 1,
#  'responded': 1,
#  '"fundamental': 1,
#  'disagreement"': 1,
#  '"great': 1,
#  'concerns': 2,
#  'taken"\'how': 1,
#  'much': 5,
#  'pain': 3,
#  "endure?'neither": 1,
#  'showing': 1,
#  'backing': 1,
#  'downthe': 1,
#  'relies': 2,
#  'less': 2,
#  "china's": 2,
#  'faring': 1,
#  'already': 2,
#  'started': 1,
#  'slowing': 1,
#  'slumped': 1,
#  'escalatedchina': 1,
#  'pumping': 1,
#  'cash': 1,
#  'heats': 1,
#  'up"the': 1,
#  'question': 4,
#  'endure?"': 1,
#  'thomas': 1,
#  'bernes': 1,
#  'distinguished': 1,
#  'centre': 1,
#  'governance': 1,
#  'innovation': 1,
#  '"they': 1,
#  'looking': 1,
#  'rejection': 1,
#  'trumpism': 1,
#  'gains': 1,
#  'strength': 1,
#  'remains': 1,
#  'power"for': 1,
#  'part': 6,
#  'appears': 1,
#  'maintain': 1,
#  'can"we': 1,
#  'changed': 1,
#  'paradigm"': 1,
#  'representative': 1,
#  ...}

# %%
for m in range(0,len(stop_words)):
    if stop_words[m] in countlist.keys():
        countlist.pop(stop_words[m])
sort=sorted(countlist.items(),key=lambda d:d[1],reverse=True)
print(sort[0:16])
# Out:
# [('us', 67), ('china', 62), ('trade', 54), ('chinese', 48), ('war', 34), ('trump', 24), ('tariffs', 22), ('beijing', 18), ('more', 16), ('will', 16), ('against', 16), ('china’s', 15), ('president', 15), ('american', 14), ('global', 14), ('last', 13)]

# %%
with open('bonus.csv','w',newline='',) as f:
    writer=csv.writer(f)
    header=['keyword','frequency']
    writer.writerow(header)
    for i in range(0,len(sort)):
        writer.writerow([sort[i][0],sort[i][1]])
